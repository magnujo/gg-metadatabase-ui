# %%
import pandas as pd

# %%
df = pd.read_csv(r"c:\Users\glj523\Downloads\query_all (4)\query_files\query_result_essential.csv", encoding='utf-16')
# Out:
# C:\Users\glj523\AppData\Local\Temp\ipykernel_5732\1312258165.py:1: DtypeWarning: Columns (2,3,4,5,10,15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"c:\Users\glj523\Downloads\query_all (4)\query_files\query_result_essential.csv", encoding='utf-16')

# %%
df[df["Museum ID/sample ID"] == "ISL22_20.2A_125"]
# Out:
#        index    FieldSampleID Archive Sample ID Robot Sample ID Library ID  \
# 42417  18236  ISL22_20.2A_125               NaN             NaN        NaN
# 63089  17592  ISL22_20.2A_125               NaN             NaN        NaN
#
#       FastQ File ID  DepthSampledCalTape Museum ID/sample ID        CGG ID  \
# 42417           NaN                  NaN     ISL22_20.2A_125  CGG_3_017646
# 63089           NaN                  NaN     ISL22_20.2A_125  CGG_3_017646
#
#       Depth height (m) asl.        Age Geological age           Lat  \
# 42417   NaN             228  1-2 ka BP   Late Holcene   64° 8´22´´N
# 63089   NaN             228  1-2 ka BP   Late Holcene   64° 8´22´´N
#
#                  Lon     GPS Country
# 42417  21° 37´27´´ W  1.05 m     NaN
# 63089  21° 37´27´´ W  1.05 m     NaN
