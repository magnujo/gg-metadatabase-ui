# %%
import pandas as pd

# %%
df = pd.read_csv(r"c:\Users\glj523\edna_robot_sample_202406101527.csv")

# %%
df.head()
# Out:
#     SubSampleID RackName        RackID PositionInRack   Mass  SampledBy  \
# 0  lv7005365986  rack175  lvl900117530            e06  182.0         mh
# 1  lv7005367348   rack52  lvl900114395            a01  192.0  mh_fm_vss
# 2  lv7005227800   rack52  lvl900114395            b01  140.0  mh_fm_vss
# 3  lv7005224976   rack52  lvl900114395            c01  172.0  mh_fm_vss
# 4  lv7005224920   rack52  lvl900114395            d01  181.0  mh_fm_vss
#
#               SamplingDate RemarksSubSampling Archive Sample ID Submitter  \
# 0  2023-11-18 00:00:00.000                NaN      lv3005574147        kk
# 1  2023-10-04 00:00:00.000                NaN      lv3005888014    bds_yw
# 2  2023-10-04 00:00:00.000                NaN      lv3005888008    bds_yw
# 3  2023-10-04 00:00:00.000                NaN      lv3005888020    bds_yw
# 4  2023-10-04 00:00:00.000                NaN      lv3005888019    bds_yw
#
#             SubmissionDate RemarksSubmission database_insert_by  \
# ...

# %%
pd.set_option('display.max_colwidth', None)

# %%
df[(df["RackID"] + df["PositionInRack"]).duplicated()]
# Out:
#       SubSampleID RackName        RackID PositionInRack   Mass SampledBy  \
# 274  lv7005365787  rack173  lvl900117532            a01  161.0    vss_fm
# 275  lv7005365786  rack173  lvl900117532            b01  172.0    vss_fm
# 276  lv7005365767  rack173  lvl900117532            c01  162.0    vss_fm
# 277  lv7005365792  rack173  lvl900117532            d01  171.0    vss_fm
#
#                 SamplingDate RemarksSubSampling Archive Sample ID Submitter  \
# 274  2023-10-19 00:00:00.000                NaN      lv3005888102        ew
# 275  2023-10-19 00:00:00.000                NaN      lv3005888109        ew
# 276  2023-10-19 00:00:00.000                NaN      lv3005888103        ew
# 277  2023-10-19 00:00:00.000                NaN      lv3005888101        ew
#
#               SubmissionDate RemarksSubmission database_insert_by  \
# 274  2023-10-19 00:00:00.000               NaN        upload_user
# 275  2023-10-19 00:00:00.000               NaN        upload_user
# ...

# %%
df[df["RackID"] == "lvl900117532"].sort_values(by="PositionInRack")
# Out:
#       SubSampleID RackName        RackID PositionInRack   Mass SampledBy  \
# 270  lv7005365783  rack173  lvl900117532            a01  184.0    vss_fm
# 274  lv7005365787  rack173  lvl900117532            a01  161.0    vss_fm
# 280  lv7005365759  rack173  lvl900117532            a02  177.0    vss_fm
# 286  lv7005365778  rack173  lvl900117532            a03  155.0    vss_fm
# 292  lv7005366083  rack173  lvl900117532            a04    NaN    vss_fm
# 298  lv7005366074  rack173  lvl900117532            a05  162.0    vss_fm
# 304  lv7005366064  rack173  lvl900117532            a06  162.0    vss_fm
# 310  lv7005365790  rack173  lvl900117532            a07  151.0    vss_fm
# 275  lv7005365786  rack173  lvl900117532            b01  172.0    vss_fm
# 271  lv7005365794  rack173  lvl900117532            b01  179.0    vss_fm
# 281  lv7005365762  rack173  lvl900117532            b02  171.0    vss_fm
# 287  lv7005365755  rack173  lvl900117532            b03  162.0    vss_fm
# ...
