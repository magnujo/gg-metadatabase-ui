# %%
import pandas as pd

# %%
pd.set_option('display.max_rows', 1000)  # Set maximum number of rows to display
pd.set_option('display.max_columns', 1000)

# %%
wldf = pd.read_excel(r"data\Wetlab Summary_Export to Magnus.xlsx", dtype=str)

# %%
wldf[wldf["Archive Sample ID"].str.startswith("18736")]
# Out:
#        Customer Name           Order Date Order ID  No Total Sample Quantity  \
# 5170  Rikai Sawafuji  2023-09-25 00:00:00   SS0062  44                    46
#
#      Robot Sample Rack Name Robot Sample Rack Barcode  \
# 5170                 Rack37              LVL900026697
#
#      Robot Sample Rack Position Robot Sample ID Archive Sample ID  ...  \
# 5170                        B08    LV7000631756             18736  ...
#
#      DNA Pooled (nmol) Expected Sequencing Data (MB)      Submitting Date  \
# 5170                20                            44  2023-11-02 00:00:00
#
#                         FastQ File ID Return DNA Return Library Return Pool  \
# 5170  LV7009023129-LV7000631756-18736      False          False       False
#
#      Pool to SeqC    Project Done Date               Library Prep Method
# 5170         True  2023-11-23 00:00:00  double strand DNA Library Method
#
# [1 rows x 49 columns]

# %%
wldf["Archive Sample ID"].apply(lambda x: x[0:5]).unique()
# Out:
# array(['1R2_1', '1R2_2', '1R2_3', '1R2_4', '1R2_5', '1R2_6', '1R2_7',
#        '1R2_8', '1R2_9', 'ExrNT', '1R3_1', '1R3_2', '1R3_3', '1R3_4',
#        '1R3_5', '1R3_6', '1R3_7', '1R3_8', '1R3_9', 'UE120', 'UE121',
#        'CGG_3', '1-4-8', 'Ext.b', 'Exrac', 'K34 P', 'LibPT', 'Ext. ',
#        'index', 'Libra', 'GeoB9', 'LV700', 'GeoB1', 'ExrPT', 'GeoB3',
#        'GeoB2', 'GeoB6', 'CGG_2', 'LibNT', 'CGG-3', 'Ryder', 'LK21-',
#        'Blank', 'AMD14', 'DA17 ', '17069', '17071', '17088', '17002',
#        '17003', '17004', '17005', '17006', '17007', '17008', '17009',
#        '17010', '17011', '17012', '17013', '17014', '17015', '17016',
#        '17017', '17018', '17019', '17020', '17021', '17022', '17023',
#        '17024', '17025', '17026', '17027', '17522', '17037', '17041',
#        '17049', 'CGG3-', 'Contr', 'CGG-0', 'CGG30', 'Qiage', 'Water',
#        'Biome', 'Robot', 'Tecan', '18281', '18282', '18283', '18284',
#        '18285', '18286', '18287', '18288', '18289', '18290', '18291',
#        '18292', '18293', '18294', '18295', '18296', '18297', '18298',
#        '18299', '18300', '18301', '18302', '18303', '18304', '18305',
#        '18306', '18307', '18308', '18309', '18310', '18311', '18312',
#        '18313', '18314', '18315', '18316', '18317', '18318', '18319',
#        '18320', '18321', '18322', '18323', '18324', '18325', '18326',
#        'LV300', 'Ginne', 'contr', 'Kit-C', 'Kit-r', '18396', '18397',
#        '18398', '18399', '18400', '18401', '18402', '18403', '18404',
#        '18405', '18406', '18407', '18408', '18409', '18410', '18411',
#        '18412', '18413', '18414', '18415', '18416', '18417', '18418',
#        '18419', '18420', '18421', '18422', '18423', '18424', '18425',
#        '18426', '18427', '18428', '18429', '18430', '18431', '18432',
#        '18433', '18434', '18435', '18436', '18437', '18438', '18439',
#        '18440', '18441', 'Bottl', 'TPL', 'Cobra', 'Tam-S', 'Nam-L',
#        'YWL1-', 'YWL2-', '18968', '18969', '18970', '18971', '18972',
#        '18973', '18974', '18975', '18976', '18977', '18978', '18979',
#        '18980', '18981', '18982', '18983', '18984', '18985', '18986',
#        '18987', '18988', '18989', '18990', '18991', '18992', '18993',
#        '18994', '18995', '18996', '18997', '18998', '18999', '19000',
#        '19001', '19002', '18728', '18729', '18730', '18731', '18732',
#        '18733', '18734', '18735', '18736', '18737', '18738', 'VB17-',
#        'AU17-', 'AU18-', 'AU23-', '24949', '24952', '24956', 'DS4-1',
#        'DS4-2', 'DS4-3', 'blank', 'Ant23', 'Negat', 'CCG3_', 'Bla23',
#        'Gir23', 'Cla23', 'lv300', 'CampC'], dtype=object)
