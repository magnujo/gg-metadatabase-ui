# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df2 = pd.read_csv(r"c:\Users\glj523\Downloads\Field Sampling Meta data reporting template 20240514.txt", sep="\t",  encoding="utf_16", dtype=str)

# %%
df2.dtypes
# Out:
# Field Sample ID                                                 object
# Master ID                                                       object
# Running Project Title                                           object
# Country/Ocean                                                   object
# Site name                                                       object
# Longitude (WGS84 decimal degrees)                               object
# Latitude (WGS84 decimal degrees)                                object
# Elevation (m asl)                                               object
# Water depth (m)                                                 object
# Sample Setting                                                  object
# Material                                                        object
# Environment                                                     object
# Age Estimate - from (ka)                                        object
# ...

# %%
df = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv', dtype=str)
# df = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv')

# %%
pd.set_option('display.max_columns', None)

# %%
df
# Out:
#     survived pclass     sex   age sibsp parch     fare embarked   class  \
# 0          0      3    male  22.0     1     0     7.25        S   Third
# 1          1      1  female  38.0     1     0  71.2833        C   First
# 2          1      3  female  26.0     0     0    7.925        S   Third
# 3          1      1  female  35.0     1     0     53.1        S   First
# 4          0      3    male  35.0     0     0     8.05        S   Third
# ..       ...    ...     ...   ...   ...   ...      ...      ...     ...
# 886        0      2    male  27.0     0     0     13.0        S  Second
# 887        1      1  female  19.0     0     0     30.0        S   First
# 888        0      3  female   NaN     1     2    23.45        S   Third
# 889        1      1    male  26.0     0     0     30.0        C   First
# 890        0      3    male  32.0     0     0     7.75        Q   Third
#
#        who adult_male deck  embark_town alive  alone
# ...

# %%
df.dtypes
# Out:
# survived       object
# pclass         object
# sex            object
# age            object
# sibsp          object
# parch          object
# fare           object
# embarked       object
# class          object
# who            object
# adult_male     object
# deck           object
# embark_town    object
# alive          object
# alone          object
# dtype: object

# %%
df2.dropna(axis="columns", how="all").nunique().reset_index().rename(columns={"index": "Column", 0: "Unique Count"}).plot()
# Out:
# <Axes: >

# %%
df2.describe()
# Out:
#        Field Sample ID   Master ID  Running Project Title Country/Ocean  \
# count               24          24                     24            24
# unique              24           1                      1             1
# top         DKHol23001  DKHol2301M  Hollerup interglacial       Denmark
# freq                 1          24                     24            24
#
#        Site name Longitude (WGS84 decimal degrees)  \
# count         24                                24
# unique         1                                 1
# top     Hollerup                         56,403167
# freq          24                                24
#
#        Latitude (WGS84 decimal degrees) Elevation (m asl) Water depth (m)  \
# count                                24                24               0
# unique                                1                 1               0
# top                            9,840336                37             NaN
# ...

# %%
categorical_columns = df.select_dtypes(include=['object', 'category']).columns
categorical_columns
# Out:
# Index(['sex', 'embarked', 'class', 'who', 'deck', 'embark_town', 'alive'], dtype='object')

# %%
l = [df[categorical_columns][col].value_counts().reset_index() for col in categorical_columns]

# %% [markdown]
# l[0]

# %%
l[3]
# Out:
#      who  count
# 0    man    537
# 1  woman    271
# 2  child     83
