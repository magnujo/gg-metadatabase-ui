# %%
# !python --version
# Out:
# Python 3.11.7

# %%
import os
import pandas as pd
from sqlalchemy import create_engine
import numpy as np
import re
from glob import glob
import scripts.ETLFunctions as etl
import psycopg2 as psycop
import sys
from datetime import datetime

# %%
file_path = r'c:\Users\glj523\Downloads\sheets\archive sample\eDNA_Archive_sampling_(231201_NKL_Hollerup_interglacial).txt'
database_table_name = 'archive_sample'
date_format = "ymd"
decimal_point = "not_relevant"
thousands_seperator = ','

clean_sheet = etl.clean_up(tsv_file_path=file_path, 
                        database_table_name=database_table_name, 
                        date_format=date_format,
                        decimal_point=decimal_point,
                        thousands_seperator=thousands_seperator)
# Out:
# check1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 7
#       4 decimal_point = "not_relevant"
#       5 thousands_seperator = ','
# ----> 7 clean_sheet = etl.clean_up(tsv_file_path=file_path,
#       8                         database_table_name=database_table_name,
#       9                         date_format=date_format,
#      10                         decimal_point=decimal_point,
#      11                         thousands_seperator=thousands_seperator)
#
# File c:\Users\glj523\Documents\github repoes\upload_web_app\scripts\ETLFunctions.py:44, in clean_up(tsv_file_path, database_table_name, date_format, decimal_point, thousands_seperator)
#      42 if database_table_name == 'archive_sample':
#      43     print("check1")
# ---> 44     sheet = parse_archive_sample(tsv_file_path, date_format, decimal_point, thousands_seperator)
#      46 elif database_table_name == 'robot_sample':
#      48     l1 = len(sheet[sheet["Robot TUBE barcode"].notnull()]) # For drop testing
#
# File c:\Users\glj523\Documents\github repoes\upload_web_app\scripts\ETLFunctions.py:147, in parse_archive_sample(file_path, date_format, decimal_point, thousands_seperator)
#     143 assert list(expected_columns) == list(sheet.columns) or list(expected_columns2) == list(sheet.columns), ("Column names and/or positions not as expected")
#     146 expected_columns = expected_columns[:-3]
# --> 147 expected_columns2 = expected_columns.copy().drop('SampledBy2') != sheet.columns or expected_columns2 != sheet.columns, ("Column names and/or positions not as expected")
#     149 # Converts column names, if they are changes to KU ID format.
#     150 if 'SampledBy' in sheet.columns:
#
# File c:\Users\glj523\AppData\Local\miniconda3\envs\db_web_app\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File c:\Users\glj523\AppData\Local\miniconda3\envs\db_web_app\Lib\site-packages\pandas\core\arraylike.py:44, in OpsMixin.__ne__(self, other)
#      42 @unpack_zerodim_and_defer("__ne__")
#      43 def __ne__(self, other):
# ---> 44     return self._cmp_method(other, operator.ne)
#
# File c:\Users\glj523\AppData\Local\miniconda3\envs\db_web_app\Lib\site-packages\pandas\core\indexes\base.py:7113, in Index._cmp_method(self, other, op)
#    7108         return arr
#    7110 if isinstance(other, (np.ndarray, Index, ABCSeries, ExtensionArray)) and len(
#    7111     self
#    7112 ) != len(other):
# -> 7113     raise ValueError("Lengths must match to compare")
#    7115 if not isinstance(other, ABCMultiIndex):
#    7116     other = extract_array(other, extract_numpy=True)
#
# ValueError: Lengths must match to compare
